# %%
import urllib.request

# %%
res = urllib.request.urlopen('https://www.runoob.com/regexp/regexp-syntax.html')

# %%
ret = res.read()

# %%
print (ret)
# Out:
# b'<!Doctype html>\n<html>\n<head>\n\t<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n  <meta property="qc:admins" content="465267610762567726375" />\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0" />\n\t<title>\xe6\xad\xa3\xe5\x88\x99\xe8\xa1\xa8\xe8\xbe\xbe\xe5\xbc\x8f &#8211; \xe8\xaf\xad\xe6\xb3\x95 | \xe8\x8f\x9c\xe9\xb8\x9f\xe6\x95\x99\xe7\xa8\x8b</title>\n\n  <link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="canonical" href="http://www.runoob.com/regexp/regexp-syntax.html" />\n<meta name="keywords" content="\xe6\xad\xa3\xe5\x88\x99\xe8\xa1\xa8\xe8\xbe\xbe\xe5\xbc\x8f &#8211; \xe8\xaf\xad\xe6\xb3\x95">\n<meta name="description" content="\xe6\xad\xa3\xe5\x88\x99\xe8\xa1\xa8\xe8\xbe\xbe\xe5\xbc\x8f - \xe8\xaf\xad\xe6\xb3\x95  \xe6\xad\xa3\xe5\x88\x99\xe8\xa1\xa8\xe8\xbe\xbe\xe5\xbc\x8f(regular expression)\xe6\x8f\x8f\xe8\xbf\xb0\xe4\xba\x86\xe4\xb8\x80\xe7\xa7\x8d\xe5\xad\x97\xe7\xac\xa6\xe4\xb8\xb2\xe5\x8c\xb9\xe9\x85\x8d
# ...

# %%
ret.decode("utf8")
# Out:
# '<!Doctype html>\n<html>\n<head>\n\t<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n  <meta property="qc:admins" content="465267610762567726375" />\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0" />\n\t<title>正则表达式 &#8211; 语法 | 菜鸟教程</title>\n\n  <link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="canonical" href="http://www.runoob.com/regexp/regexp-syntax.html" />\n<meta name="keywords" content="正则表达式 &#8211; 语法">\n<meta name="description" content="正则表达式 - 语法  正则表达式(regular expression)描述了一种字符串匹配的模式（pattern），可以用来检查一个串是否含有某种子串、将匹配的子串替换或者从某个串中取出符合某个条件的子串等。 例如：  runoo+b，可以匹配 runoob、runooob、runoooooob 等，+ 号代表前面的字符必须至少出现一次（1次或多次）。   runoo*b，可以匹配 runob、runoob、runoooooob 等..">\n\t\t\n\t<link rel="shortcut icon" href="//static.runoob.com/images/favicon.ico" mce_href="//static.runoob.com/images/favicon.ico" type="image/x-icon" >\n\t<link rel="stylesheet" href="/wp-content/themes/runoob/style.css?v=1.154" type="text/css" media="all" />\t\
# ...
